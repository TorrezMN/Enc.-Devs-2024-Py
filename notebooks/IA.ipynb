# %%
#######################
# CONFIG ZONE
#######################

# Importing Libs
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

from collections import Counter
import numpy as np

# My Tools
import milanesas.eda_helper as eh
from tools.helpers import (
    get_column_uniques,
    get_column_uniques_count,
    plot_grouped_by_category_barh_charts,
    barh_chart_unique_values,
    print_unique_normalized_values_by_group,
    make_vertical_grouped_chart,
    plot_uniques_count,
    uniques_count_to_dataframe,
    grouped_grid_barh_chart,
    barh_chart_unique_values_grid,
    md_table,
    md_group_table,
)


# %matplotlib inline

# Reseting figure size params.
plt.rcParams["figure.figsize"] = [12, 7]
# Setting seaborn as default plotting lib.
sns.set()
sns.set_palette("pastel")

# %%
df = pd.read_csv("../data/data_fixed.csv")

# %% [markdown]
# ### 5. **Artificial Intelligence**
#    - ¿Usás regularmente* alguna de estas herramientas de I.A. para ayudarte en tu proceso de desarrollo?
#    - ¿Creés que la inteligencia artificial reemplazará al desarrollador?

# %% [markdown]
#    - ¿Usás regularmente* alguna de estas herramientas de I.A. para ayudarte en tu proceso de desarrollo?

# %%
ia_use_df = uniques_count_to_dataframe(get_column_uniques_count(df, "use_AI_tools"))

# %%
ia_use_df
# Out:
#             category  count
# 0            ChatGPT    300
# 1     Github Copilot    100
# 2        Google Bard     49
# 3            Bing AI     45
# 4          Notion AI     17
# 5       WolframAlpha      5
# 6  AWS CodeWhisperer      5
# 7            Codeium      4
# 8          Claude.ai      2
# 9            Copilot      1

# %%
md_table("ia_use_total_count_table", ia_use_df, "Use of IA total count.")
# Out:
#         <center>
#         <a id="ia_use_total_count_table_iI13e"></a>
#
#         | category          |   count |
# |:------------------|--------:|
# | ChatGPT           |     300 |
# | Github Copilot    |     100 |
# | Google Bard       |      49 |
# | Bing AI           |      45 |
# | Notion AI         |      17 |
# | WolframAlpha      |       5 |
# | AWS CodeWhisperer |       5 |
# | Codeium           |       4 |
# | Claude.ai         |       2 |
# | Copilot           |       1 |
#
#         <p style="text-align: center;"><em>Use of IA total count.</em></p>
#         </center>
#         <br/>
#         <br/>

# %%
plot_uniques_count(ia_use_df, "Use IA tools regularly.", "Count", "Tool")

# %% [markdown]
#    - ¿Creés que la inteligencia artificial reemplazará al desarrollador?

# %%
ai_replacement_df = uniques_count_to_dataframe(
    get_column_uniques_count(df, "AI_replace_dev")
)

# %%
plot_uniques_count(ai_replacement_df, "Will AI replace dev's?\n", "count", "resp.")

# %% [markdown]
# # AI Tools usage

# %%
# print uniques in column.
ai_usage_uniques_df = uniques_count_to_dataframe(
    get_column_uniques_count(df, "use_AI_tools")
)

# %%
plot_uniques_count(ai_usage_uniques_df, "AI usage counts.", "Count.", "AI")

# %% [markdown]
# ## AI TOOLS - work_mode

# %%
# Mostrar uniques in 'work_mode' column.

# %%
get_column_uniques(df, "work_mode")
# Out:
# ['remote', 'onsite', 'Hibrído', 'none']

# %%
barh_chart_unique_values(
    df, "use_AI_tools", "work_mode", "AI tools usage by work mode.", "Work mode."
)

# %% [markdown]
# ## AI TOOLS - employment_mode

# %%
md_group_table(
    "ai_tools_by_employment_mode_table",
    df,
    "employment_mode",
    "use_AI_tools",
    "Use AI tools by enployment mode.",
)
# Out:
# <center>
#     <a id="ai_tools_by_employment_mode_table_o7Bju"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 52% |
# | Github Copilot, ChatGPT | 7% |
# | ChatGPT, Github Copilot | 7% |
# | Google Bard, ChatGPT | 5% |
# | ChatGPT, Bing AI | 2% |
# | ChatGPT, Google Bard | 2% |
# | Bing AI, ChatGPT | 1% |
# | Codeium | 1% |
# | ChatGPT, Google Bard, Bing AI | 0% |
# | Google Bard | 0% |
# | Github Copilot, ChatGPT, Google Bard | 0% |
# | ChatGPT, Github Copilot, Google Bard | 0% |
# | Github Copilot | 0% |
# | Bing AI | 0% |
# | WolframAlpha, ChatGPT, Claude Ai | 0% |
# | ChatGPT, Notion AI, Github Copilot | 0% |
# | Bing AI, ChatGPT, Github Copilot | 0% |
# | Claude | 0% |
# | WolframAlpha, Github Copilot | 0% |
# | Bing AI, Google Bard, ChatGPT, WolframAlpha, Notion AI | 0% |
# | Google Bard, Bing AI, ChatGPT, Claude.ai | 0% |
# | ChatGPT, Codeium | 0% |
# | Notion AI, ChatGPT, Bing AI | 0% |
# | Google Bard, ChatGPT, Bing AI | 0% |
# | Bing AI, Github Copilot, ChatGPT | 0% |
# | ChatGPT, Bing AI, Github Copilot | 0% |
# | ChatGPT, AWS CodeWhisperer, Github Copilot, Notion AI, Bing AI, Google Bard | 0% |
# | Github Copilot, Notion AI, Google Bard, ChatGPT | 0% |
# | ChatGPT, Google Bard, Bing AI, Github Copilot | 0% |
# | Bing AI, Github Copilot | 0% |
# | Google Bard, Bing AI, ChatGPT | 0% |
# | ChatGPT, Bing AI, Google Bard | 0% |
# | ChatGPT, Github Copilot, TabNine | 0% |
# | ChatGPT, Claude.ai | 0% |
# | Github Copilot, Bing AI | 0% |
# | Google Bard, Github Copilot, ChatGPT, Notion AI | 0% |
# | ChatGPT, Google Bard, CODEGEEX | 0% |
# | Bing AI, ChatGPT, Notion AI | 0% |
# | ChatGPT, Google Bard, Github Copilot, Bing AI | 0% |
# | Google Bard, ChatGPT, Notion AI | 0% |
# | Talkai | 0% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by enployment mode. - Empleador local (Paraguay)</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_employment_mode_table_8s1cM"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 34% |
# | ChatGPT, Github Copilot | 12% |
# | Github Copilot, ChatGPT | 10% |
# | Github Copilot | 8% |
# | ChatGPT, Bing AI | 4% |
# | Notion AI, Github Copilot, ChatGPT | 2% |
# | ChatGPT, Github Copilot, Google Bard | 2% |
# | Google Bard, ChatGPT, Notion AI, Bing AI, Github Copilot | 1% |
# | Notion AI | 1% |
# | Bing AI, AWS CodeWhisperer, ChatGPT | 1% |
# | Github Copilot, WolframAlpha | 1% |
# | Bing AI, ChatGPT | 1% |
# | Bing AI, ChatGPT, AWS CodeWhisperer, Google Bard | 1% |
# | Github Copilot, AWS CodeWhisperer, ChatGPT, Google Bard | 1% |
# | Microsoft Copilot | 1% |
# | Github Copilot, Notion AI, ChatGPT | 1% |
# | ChatGPT, Google Bard | 1% |
# | Github Copilot, IntelliJ Assistant  | 1% |
# | Google Bard, ChatGPT | 1% |
# | ChatGPT, Genesis, Copilot | 1% |
# | AiDE | 1% |
# | ChatGPT, Google Bard, Github Copilot | 1% |
# | ChatGPT, Github Copilot, Notion AI, Bing AI | 1% |
# | Codium AI | 1% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by enployment mode. - foreign_employer</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_employment_mode_table_6tE6w"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 48% |
# | ChatGPT, Github Copilot | 14% |
# | Bing AI, ChatGPT | 7% |
# | Google Bard, Google Geminis | 3% |
# | ChatGPT, Bing AI | 3% |
# | ChatGPT, Bing AI, Google Bard | 3% |
# | ChatGPT, Unity Muse | 3% |
# | Google Bard, ChatGPT | 3% |
# | Notion AI | 3% |
# | Github Copilot, ChatGPT | 3% |
# | Bing AI | 3% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by enployment mode. - freelance</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_employment_mode_table_gzNgC"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 44% |
# | ChatGPT, Github Copilot | 16% |
# | Github Copilot, ChatGPT | 8% |
# | Github Copilot | 4% |
# | Github Copilot, Notion AI, AWS CodeWhisperer | 4% |
# | WolframAlpha, ChatGPT | 4% |
# | Bing AI, ChatGPT, Github Copilot | 4% |
# | ChatGPT, Google Bard | 4% |
# | Notion AI, ChatGPT, Bing AI | 4% |
# | Bing AI, Github Copilot, ChatGPT | 4% |
# | Github Copilot, Bing AI | 4% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by enployment mode. - local_with_foreign_clients</em></p>
#     <br/>
# </center>

# %% [markdown]
# ## AI TOOLS - role

# %%
md_group_table("ai_tools_by_role", df, "role", "use_AI_tools", "Use AI tools by role.")
# Out:
# <center>
#     <a id="ai_tools_by_role_o8mZG"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_8sJPp"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Bing AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - desktop_apps, qa_testing, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_P8Ema"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_arch</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_sjovw"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - desktop_apps, db_admin, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_WnmUV"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 50% |
# | ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_cHWUq"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 46% |
# | ChatGPT, Github Copilot | 15% |
# | Google Bard, ChatGPT | 7% |
# | ChatGPT, Github Copilot, Google Bard | 7% |
# | Github Copilot, ChatGPT | 2% |
# | AiDE | 2% |
# | Github Copilot, Notion AI, ChatGPT | 2% |
# | Github Copilot | 2% |
# | ChatGPT, Google Bard | 2% |
# | Google Bard, ChatGPT, Bing AI | 2% |
# | Github Copilot, ChatGPT, Google Bard | 2% |
# | Claude | 2% |
# | Codium AI | 2% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_sIFL1"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, Google Geminis | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, desktop_apps, db_admin, dev_ops, sre</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_0s9dK"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 49% |
# | Github Copilot, ChatGPT | 11% |
# | ChatGPT, Github Copilot | 8% |
# | ChatGPT, Bing AI | 8% |
# | ChatGPT, Google Bard | 4% |
# | Github Copilot | 2% |
# | ChatGPT, Github Copilot, Notion AI, Bing AI | 1% |
# | ChatGPT, Google Bard, Github Copilot, Bing AI | 1% |
# | Bing AI, Github Copilot, ChatGPT | 1% |
# | Notion AI | 1% |
# | Notion AI, Github Copilot, ChatGPT | 1% |
# | ChatGPT, Codeium | 1% |
# | Bing AI | 1% |
# | Google Bard, Bing AI, ChatGPT, Claude.ai | 1% |
# | Github Copilot, Bing AI | 1% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_ZqWG2"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, qa_testing</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_wkRWN"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_8ZNzD"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - qa_tester</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_y3qes"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 66% |
# | ChatGPT, Github Copilot | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_qZ1N0"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, desktop_apps, db_admin, data_analyst, data_eng, data_sci, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_s7Qji"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, ChatGPT, Notion AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - digital_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_qXcYc"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 50% |
# | ChatGPT, Github Copilot | 16% |
# | Github Copilot, Bing AI | 16% |
# | Github Copilot, ChatGPT, Google Bard | 16% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_cAMny"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - sys_coord</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_185Vx"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - it</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_fW5rp"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI | 50% |
# | ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_G2PlM"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 40% |
# | ChatGPT, Github Copilot | 20% |
# | Google Bard, Github Copilot, ChatGPT, Notion AI | 20% |
# | Github Copilot | 20% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_jPKNJ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Google Bard, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, game_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_G79O3"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 50% |
# | Bing AI, ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, full_stack_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Giy5r"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, ChatGPT | 37% |
# | Github Copilot, ChatGPT | 12% |
# | Microsoft Copilot | 12% |
# | ChatGPT | 12% |
# | ChatGPT, Bing AI | 12% |
# | ChatGPT, Github Copilot | 12% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_RJgjN"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Codeium | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, mobile_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_In5RI"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 36% |
# | Github Copilot, ChatGPT | 18% |
# | Github Copilot | 18% |
# | ChatGPT, Google Bard | 9% |
# | Github Copilot, IntelliJ Assistant  | 9% |
# | ChatGPT, Google Bard, Bing AI | 9% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_80TeU"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 40% |
# | Github Copilot, ChatGPT | 20% |
# | ChatGPT, Google Bard, CODEGEEX | 20% |
# | ChatGPT | 20% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_PhpUg"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - mobile_dev, desktop_apps, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_5PLld"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 66% |
# | ChatGPT, Genesis, Copilot | 11% |
# | Google Bard | 11% |
# | Bing AI, ChatGPT | 11% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_1HWsa"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 83% |
# | Github Copilot, AWS CodeWhisperer, ChatGPT, Google Bard | 16% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_nuLZ0"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, db_admin, ai_specialist, sales</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_kbGEv"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - support_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_DtXu9"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 55% |
# | ChatGPT, Github Copilot | 22% |
# | ChatGPT, Bing AI, Google Bard | 11% |
# | Github Copilot | 11% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_t3CZ6"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 33% |
# | ChatGPT, Github Copilot, Google Bard | 33% |
# | ChatGPT | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, full_stack_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_PYanG"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 66% |
# | Google Bard, ChatGPT | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_6ncJi"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 25% |
# | ChatGPT | 25% |
# | ChatGPT, Github Copilot | 25% |
# | ChatGPT, Notion AI, Github Copilot | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_jzPVR"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_eng, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_gyPv8"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, ChatGPT, Notion AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, qa_testing, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_aQCJn"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 50% |
# | Google Bard, ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, full_stack_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_kisgk"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, desktop_apps, qa_testing, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_cttAT"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_3ZGJ4"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 60% |
# | Google Bard, ChatGPT | 20% |
# | ChatGPT, Github Copilot | 20% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - qa_testing</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_1VMNs"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, dev_ops, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_DD7iF"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, dev_ops, sys_arch</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_tPdtL"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI | 50% |
# | ChatGPT, Github Copilot | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_WVlf0"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, mobile_dev, qa_testing</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_mOYqY"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, db_admin, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_nyBFR"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Codeium | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, full_stack_dev, qa_testing, db_admin, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_8ZFQj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Claude.ai | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - qa_testing, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_mel3f"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Bing AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, db_admin, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_mgal1"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_sci, ml_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_etpjA"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot, TabNine | 25% |
# | ChatGPT | 25% |
# | ChatGPT, Github Copilot | 25% |
# | Github Copilot, ChatGPT | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_ljojV"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, mobile_dev, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_pw5x4"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, embedded_sys_dev, db_admin, proj_lead, data_analyst, data_eng, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_uMgYd"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 66% |
# | ChatGPT, Bing AI, Google Bard | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_analyst, data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_MpMNH"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_sci</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_B9DDQ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, mobile_dev, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_9KuHX"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, AWS CodeWhisperer, Github Copilot, Notion AI, Bing AI, Google Bard | 50% |
# | ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_dwmgo"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, Bing AI, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, qa_testing, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_hESZt"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - solution_arch</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_GZMuZ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 60% |
# | Github Copilot, Notion AI, AWS CodeWhisperer | 20% |
# | Bing AI, ChatGPT, AWS CodeWhisperer, Google Bard | 20% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_ZLyPM"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 50% |
# | ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_eDyLf"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, full_stack_dev, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_FmYT1"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, full_stack_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_koswe"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, ChatGPT, Notion AI, Bing AI, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, qa_testing, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_6qlGp"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - software_arch</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Fzvyy"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Unity Muse | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - game_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_9SxqH"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, mobile_dev, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_gE3mW"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, qa_testing</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_I3OxA"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_uFPsz"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, full_stack_dev, mobile_dev, embedded_sys_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_71Oit"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - proj_lead, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_GKt2r"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, embedded_sys_dev, desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Ucck0"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_eujYa"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Google Bard | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, desktop_apps, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_4QvN7"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - qa_testing, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_B7T2b"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Google Bard, Bing AI, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - db_admin, proj_lead, data_analyst, data_eng, data_sci, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_cPQvz"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, Notion AI, Google Bard, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - it_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_1eWHx"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - mobile_dev, community_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_5n576"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Bing AI | 50% |
# | ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_5jCpR"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, ChatGPT | 50% |
# | ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_p9mQM"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_ZzLqQ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, embedded_sys_dev, desktop_apps, db_admin, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_bTahE"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Notion AI, Github Copilot, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, mobile_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_uZbVD"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - tech_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Vjyfs"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - desktop_apps, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_UFQIQ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - db_admin, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_KMDHc"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | WolframAlpha, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - desktop_apps, qa_testing, db_admin, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_DgpWy"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 50% |
# | Notion AI | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_gIfpH"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, embedded_sys_dev, data_eng, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_chUtP"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, crm</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_fJ9Kr"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, db_admin, proj_lead, data_eng, data_sci, dev_ops, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_fsYpO"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, cloud_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_qwDWN"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, WolframAlpha | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, proj_lead, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_5b9Xl"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, full_stack_dev, data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_EFCsA"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_X8FHO"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, full_stack_dev, platform_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_lz4uE"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Notion AI, ChatGPT, Bing AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - proj_lead, data_analyst, data_eng, data_sci</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_7BUx3"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, full_stack_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_ZDRZl"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, team_lead </em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_vUX4z"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, full_stack_dev, desktop_apps, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_cbt9O"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, AWS CodeWhisperer, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, data_analyst, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_jKgAw"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 33% |
# | Bing AI, Github Copilot, ChatGPT | 33% |
# | Github Copilot, ChatGPT | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_gXAp5"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_analyst, data_eng, data_sci, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_otfKf"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, mobile_dev, qa_testing</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_W9Ze6"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Google Bard | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_0Ux0h"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_analyst, data_sci</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_TmFaI"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Codeium | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, qa_testing, proj_lead, dev_ops, ux_ui, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_NjlIU"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, Google Bard, ChatGPT, WolframAlpha, Notion AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - jr_electrical_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_8tZtP"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, desktop_apps, db_admin, data_analyst, data_eng, data_sci, dev_ops, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_4tEHO"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Notion AI, ChatGPT, Bing AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, embedded_sys_dev, desktop_apps, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_A14Cn"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, mobile_dev, desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_8JXh6"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - quality_analyst </em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_5wlZC"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, game_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_q0jWU"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, qa_testing</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Ycou1"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, data_eng, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_qaPnU"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, data_analyst, data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_yiuXq"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_uQvGJ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Hu39R"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Bing AI, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - sys_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_2NjLj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Google Bard, Bing AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, mobile_dev, desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_8ru02"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_hfaS0"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, mobile_dev, desktop_apps, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_qVjfE"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, data_eng, data_sci</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_0jjPr"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, embedded_sys_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_3E7Kr"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | WolframAlpha, ChatGPT, Claude Ai | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, db_admin, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_dOZix"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Google Bard | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, desktop_apps, db_admin, data_eng, data_sci, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_YOg2E"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, db_admin, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_vm4fj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_WuqU2"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | WolframAlpha, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, embedded_sys_dev, proj_lead, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_3bND6"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - it_auditor</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_ak0PR"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, full_stack_dev, desktop_apps, data_analyst, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_MZoTC"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, mobile_dev, db_admin, proj_lead, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_2dLDf"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, platform_eng </em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_04YHu"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, desktop_apps, qa_testing, db_admin, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_2iW3I"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_tcFto"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_analyst, data_eng, data_sci</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Qta2p"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_xhrq4"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Talkai | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - analyst_qa</em></p>
#     <br/>
# </center>

# %%
md_group_table("ai_tools_by_role", df, "role", "use_AI_tools", "Use AI tools by role.")
# Out:
# <center>
#     <a id="ai_tools_by_role_iA55f"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_ATJpL"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Bing AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - desktop_apps, qa_testing, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_cNSAf"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_arch</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_oHNrC"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - desktop_apps, db_admin, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_0J79w"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 50% |
# | ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_S23OU"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 46% |
# | ChatGPT, Github Copilot | 15% |
# | Google Bard, ChatGPT | 7% |
# | ChatGPT, Github Copilot, Google Bard | 7% |
# | Github Copilot, ChatGPT | 2% |
# | AiDE | 2% |
# | Github Copilot, Notion AI, ChatGPT | 2% |
# | Github Copilot | 2% |
# | ChatGPT, Google Bard | 2% |
# | Google Bard, ChatGPT, Bing AI | 2% |
# | Github Copilot, ChatGPT, Google Bard | 2% |
# | Claude | 2% |
# | Codium AI | 2% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_OJYUM"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, Google Geminis | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, desktop_apps, db_admin, dev_ops, sre</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_5PNJT"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 49% |
# | Github Copilot, ChatGPT | 11% |
# | ChatGPT, Github Copilot | 8% |
# | ChatGPT, Bing AI | 8% |
# | ChatGPT, Google Bard | 4% |
# | Github Copilot | 2% |
# | ChatGPT, Github Copilot, Notion AI, Bing AI | 1% |
# | ChatGPT, Google Bard, Github Copilot, Bing AI | 1% |
# | Bing AI, Github Copilot, ChatGPT | 1% |
# | Notion AI | 1% |
# | Notion AI, Github Copilot, ChatGPT | 1% |
# | ChatGPT, Codeium | 1% |
# | Bing AI | 1% |
# | Google Bard, Bing AI, ChatGPT, Claude.ai | 1% |
# | Github Copilot, Bing AI | 1% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_H4t7I"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, qa_testing</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_AS7Og"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_8SWeJ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - qa_tester</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_fp3aK"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 66% |
# | ChatGPT, Github Copilot | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_nsFVs"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, desktop_apps, db_admin, data_analyst, data_eng, data_sci, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_CeOjX"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, ChatGPT, Notion AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - digital_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_t2MfF"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 50% |
# | ChatGPT, Github Copilot | 16% |
# | Github Copilot, Bing AI | 16% |
# | Github Copilot, ChatGPT, Google Bard | 16% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_d91iB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - sys_coord</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_8cmAG"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - it</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_PvlZo"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI | 50% |
# | ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_sFn74"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 40% |
# | ChatGPT, Github Copilot | 20% |
# | Google Bard, Github Copilot, ChatGPT, Notion AI | 20% |
# | Github Copilot | 20% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_TlI2H"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Google Bard, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, game_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_fqo30"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 50% |
# | Bing AI, ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, full_stack_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_GM14S"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, ChatGPT | 37% |
# | Github Copilot, ChatGPT | 12% |
# | Microsoft Copilot | 12% |
# | ChatGPT | 12% |
# | ChatGPT, Bing AI | 12% |
# | ChatGPT, Github Copilot | 12% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_eXXLv"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Codeium | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, mobile_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_KRyhX"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 36% |
# | Github Copilot, ChatGPT | 18% |
# | Github Copilot | 18% |
# | ChatGPT, Google Bard | 9% |
# | Github Copilot, IntelliJ Assistant  | 9% |
# | ChatGPT, Google Bard, Bing AI | 9% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_7P8pA"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 40% |
# | Github Copilot, ChatGPT | 20% |
# | ChatGPT, Google Bard, CODEGEEX | 20% |
# | ChatGPT | 20% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Nn9Mf"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - mobile_dev, desktop_apps, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_YvwWn"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 66% |
# | ChatGPT, Genesis, Copilot | 11% |
# | Google Bard | 11% |
# | Bing AI, ChatGPT | 11% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_nzH5H"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 83% |
# | Github Copilot, AWS CodeWhisperer, ChatGPT, Google Bard | 16% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_gbjMV"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, db_admin, ai_specialist, sales</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_1KZiZ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - support_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_hY7Mz"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 55% |
# | ChatGPT, Github Copilot | 22% |
# | ChatGPT, Bing AI, Google Bard | 11% |
# | Github Copilot | 11% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_UR9Pt"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 33% |
# | ChatGPT, Github Copilot, Google Bard | 33% |
# | ChatGPT | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, full_stack_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_tJYbu"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 66% |
# | Google Bard, ChatGPT | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_xiXKk"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 25% |
# | ChatGPT | 25% |
# | ChatGPT, Github Copilot | 25% |
# | ChatGPT, Notion AI, Github Copilot | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_mq4sI"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_eng, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_BWQ7v"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, ChatGPT, Notion AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, qa_testing, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_0Q1Od"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 50% |
# | Google Bard, ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, full_stack_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_COzBi"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, desktop_apps, qa_testing, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_A7BXQ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_EszM4"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 60% |
# | Google Bard, ChatGPT | 20% |
# | ChatGPT, Github Copilot | 20% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - qa_testing</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_JEDu7"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, dev_ops, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Zcb1z"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, dev_ops, sys_arch</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_t85SY"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI | 50% |
# | ChatGPT, Github Copilot | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Gueq5"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, mobile_dev, qa_testing</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_uu0vj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, db_admin, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_hUJdF"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Codeium | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, full_stack_dev, qa_testing, db_admin, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_hRdpI"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Claude.ai | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - qa_testing, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_QqMmS"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Bing AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, db_admin, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_S6z3M"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_sci, ml_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_882SQ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot, TabNine | 25% |
# | ChatGPT | 25% |
# | ChatGPT, Github Copilot | 25% |
# | Github Copilot, ChatGPT | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Ow3DW"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, mobile_dev, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_JTWDm"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, embedded_sys_dev, db_admin, proj_lead, data_analyst, data_eng, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_eNqoc"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 66% |
# | ChatGPT, Bing AI, Google Bard | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_analyst, data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_yKs9E"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_sci</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_3bQVl"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, mobile_dev, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_ZfTX7"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, AWS CodeWhisperer, Github Copilot, Notion AI, Bing AI, Google Bard | 50% |
# | ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_hpeWC"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, Bing AI, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, qa_testing, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_3dILk"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - solution_arch</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Ugtff"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 60% |
# | Github Copilot, Notion AI, AWS CodeWhisperer | 20% |
# | Bing AI, ChatGPT, AWS CodeWhisperer, Google Bard | 20% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_F9Aij"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 50% |
# | ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_7J0Nn"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, full_stack_dev, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_aPFdP"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, full_stack_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_9vzkS"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, ChatGPT, Notion AI, Bing AI, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, qa_testing, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_QkCI0"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - software_arch</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_BYNMX"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Unity Muse | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - game_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_ba79S"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, mobile_dev, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_9GRqP"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, qa_testing</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Me79u"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_OsBeP"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, full_stack_dev, mobile_dev, embedded_sys_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Opti8"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - proj_lead, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_8v0xS"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, embedded_sys_dev, desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Gjx9L"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_CW6kx"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Google Bard | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, desktop_apps, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_p02kL"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - qa_testing, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_VgP3T"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Google Bard, Bing AI, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - db_admin, proj_lead, data_analyst, data_eng, data_sci, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_9DVju"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, Notion AI, Google Bard, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - it_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_7LdSi"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - mobile_dev, community_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_v47cy"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Bing AI | 50% |
# | ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_x3pOu"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, ChatGPT | 50% |
# | ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_d2AZz"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_AsB4C"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, embedded_sys_dev, desktop_apps, db_admin, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_JNdQ9"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Notion AI, Github Copilot, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, mobile_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_tNLCg"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - tech_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_lPVtB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - desktop_apps, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_X4ASh"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - db_admin, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_DrVzi"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | WolframAlpha, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - desktop_apps, qa_testing, db_admin, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_b75yZ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 50% |
# | Notion AI | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_FqwL0"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, embedded_sys_dev, data_eng, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_IQIMf"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, crm</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_4QufR"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, db_admin, proj_lead, data_eng, data_sci, dev_ops, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_wSNww"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, cloud_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Z6rno"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, WolframAlpha | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, proj_lead, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_ODOoU"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, full_stack_dev, data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_DMqdA"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_8a7Fd"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, full_stack_dev, platform_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Lyi9S"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Notion AI, ChatGPT, Bing AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - proj_lead, data_analyst, data_eng, data_sci</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_uy8JG"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, full_stack_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_A1oRs"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, team_lead </em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_e9trB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, full_stack_dev, desktop_apps, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_0TJO5"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, AWS CodeWhisperer, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, data_analyst, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_IT2qM"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 33% |
# | Bing AI, Github Copilot, ChatGPT | 33% |
# | Github Copilot, ChatGPT | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_VCuYM"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_analyst, data_eng, data_sci, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_JHgZW"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, mobile_dev, qa_testing</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_27xTB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Google Bard | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_QpkrC"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_analyst, data_sci</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_YUbAj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Codeium | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, qa_testing, proj_lead, dev_ops, ux_ui, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_4emBg"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, Google Bard, ChatGPT, WolframAlpha, Notion AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - jr_electrical_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_bGoRP"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, desktop_apps, db_admin, data_analyst, data_eng, data_sci, dev_ops, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_pENkP"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Notion AI, ChatGPT, Bing AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, embedded_sys_dev, desktop_apps, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_JjmMX"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, mobile_dev, desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_NvTmj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - quality_analyst </em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_YmN42"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, game_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_O88sO"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, qa_testing</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_h3hvn"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, data_eng, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_EsmWk"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, data_analyst, data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_zgBRe"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_hKlu1"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_YogS8"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Bing AI, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - sys_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_VnYVT"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Google Bard, Bing AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, mobile_dev, desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_uSD2A"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_fiQPz"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, mobile_dev, desktop_apps, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_AHcYy"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - frontend_dev, data_eng, data_sci</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_yXOjq"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, embedded_sys_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_R6VAp"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | WolframAlpha, ChatGPT, Claude Ai | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, db_admin, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_WnWE9"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Google Bard | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, desktop_apps, db_admin, data_eng, data_sci, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_7giDG"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, db_admin, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_tsweN"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_kxRBB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | WolframAlpha, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, embedded_sys_dev, proj_lead, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_8LAKt"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - it_auditor</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_69zTV"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, full_stack_dev, desktop_apps, data_analyst, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_dB2Bx"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - full_stack_dev, mobile_dev, db_admin, proj_lead, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_QmsrS"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, platform_eng </em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_tvc5h"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, desktop_apps, qa_testing, db_admin, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_Bgf1a"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, frontend_dev, full_stack_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_mAJVZ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - data_analyst, data_eng, data_sci</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_nK6bj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - backend_dev, data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_role_fd144"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Talkai | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by role. - analyst_qa</em></p>
#     <br/>
# </center>

# %% [markdown]
# ## AI TOOLS - prog_skills_in_role

# %%
md_group_table(
    "ai_tools_by_prog_skills_in_role",
    df,
    "prog_skills_in_role",
    "use_AI_tools",
    "Use AI tools by programming skills in role.",
)
# Out:
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_FQEW2"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - devops_dataops, scientific_researcher</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_DxlSA"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Bing AI | 33% |
# | ChatGPT | 33% |
# | Google Bard, Bing AI, ChatGPT, Claude.ai | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - sys_admin, devops_dataops, designer</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_GVKE3"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 53% |
# | Github Copilot, ChatGPT | 10% |
# | ChatGPT, Github Copilot | 6% |
# | Google Bard, ChatGPT | 3% |
# | Google Bard | 3% |
# | Bing AI, ChatGPT | 3% |
# | WolframAlpha, ChatGPT, Claude Ai | 1% |
# | ChatGPT, Google Bard, Bing AI | 1% |
# | Bing AI, ChatGPT, Github Copilot | 1% |
# | Github Copilot, ChatGPT, Google Bard | 1% |
# | Github Copilot, Notion AI, Google Bard, ChatGPT | 1% |
# | Microsoft Copilot | 1% |
# | ChatGPT, Google Bard | 1% |
# | Github Copilot | 1% |
# | ChatGPT, Google Bard, Github Copilot | 1% |
# | ChatGPT, Github Copilot, Notion AI, Bing AI | 1% |
# | ChatGPT, Bing AI | 1% |
# | Codium AI | 1% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - sys_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_2EItr"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 53% |
# | ChatGPT, Github Copilot | 10% |
# | Github Copilot, ChatGPT | 6% |
# | Google Bard, ChatGPT | 4% |
# | ChatGPT, Bing AI | 2% |
# | WolframAlpha, Github Copilot | 2% |
# | Bing AI, Github Copilot, ChatGPT | 2% |
# | Notion AI, ChatGPT, Bing AI | 2% |
# | Github Copilot, WolframAlpha | 2% |
# | Notion AI, Github Copilot, ChatGPT | 2% |
# | Bing AI, ChatGPT, AWS CodeWhisperer, Google Bard | 2% |
# | ChatGPT, Github Copilot, Google Bard | 2% |
# | Bing AI, Github Copilot | 2% |
# | ChatGPT, Google Bard | 2% |
# | ChatGPT, Github Copilot, TabNine | 2% |
# | Google Bard, Github Copilot, ChatGPT, Notion AI | 2% |
# | Github Copilot, Bing AI | 2% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - devops_dataops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_Mjv70"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 50% |
# | Google Bard, Google Geminis | 16% |
# | Github Copilot, Notion AI, AWS CodeWhisperer | 16% |
# | Google Bard, ChatGPT, Bing AI | 16% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - sys_admin, devops_dataops, scientific_researcher</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_ep7DI"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 44% |
# | Github Copilot, ChatGPT | 22% |
# | Github Copilot | 11% |
# | ChatGPT, AWS CodeWhisperer, Github Copilot, Notion AI, Bing AI, Google Bard | 11% |
# | ChatGPT, Github Copilot | 11% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - educator</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_MGXpg"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 48% |
# | ChatGPT, Github Copilot | 11% |
# | Codeium | 7% |
# | ChatGPT, Genesis, Copilot | 3% |
# | ChatGPT, Google Bard, Github Copilot, Bing AI | 3% |
# | Github Copilot, ChatGPT | 3% |
# | ChatGPT, Bing AI | 3% |
# | Github Copilot, AWS CodeWhisperer, ChatGPT, Google Bard | 3% |
# | Google Bard, ChatGPT | 3% |
# | Notion AI, ChatGPT, Bing AI | 3% |
# | Notion AI | 3% |
# | Bing AI, ChatGPT | 3% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - sys_admin, devops_dataops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_13A7R"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 42% |
# | ChatGPT, Google Bard | 10% |
# | ChatGPT, Github Copilot | 10% |
# | ChatGPT, Bing AI, Google Bard | 5% |
# | Codeium | 5% |
# | ChatGPT, Unity Muse | 5% |
# | ChatGPT, Bing AI | 5% |
# | Bing AI, ChatGPT, Github Copilot | 5% |
# | Bing AI, AWS CodeWhisperer, ChatGPT | 5% |
# | Github Copilot, ChatGPT | 5% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - designer</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_5JAj7"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot, ChatGPT | 66% |
# | ChatGPT, Bing AI | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - devops_dataops, designer</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_ATknO"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Bing AI, ChatGPT, Notion AI | 25% |
# | Google Bard, ChatGPT, Notion AI, Bing AI, Github Copilot | 25% |
# | ChatGPT, Google Bard, Bing AI, Github Copilot | 25% |
# | ChatGPT | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - sys_admin, scientific_researcher, educator</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_EDZBZ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 60% |
# | Github Copilot | 20% |
# | ChatGPT, Github Copilot | 20% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - scientific_researcher</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_7vIr6"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 60% |
# | Google Bard, ChatGPT | 10% |
# | Bing AI | 10% |
# | Notion AI, Github Copilot, ChatGPT | 10% |
# | ChatGPT, Github Copilot | 10% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - sys_admin, designer</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_DL53b"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Claude.ai | 25% |
# | Google Bard, Bing AI, ChatGPT | 25% |
# | ChatGPT | 25% |
# | ChatGPT, Google Bard, Bing AI | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - sys_admin, scientific_researcher</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_fEAfD"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 70% |
# | Bing AI | 10% |
# | ChatGPT, Google Bard | 10% |
# | ChatGPT, Bing AI | 10% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - sys_admin, educator</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_O2I8q"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - scientific_researcher, designer, educator</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_tLPxb"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 66% |
# | ChatGPT, Github Copilot | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - sys_admin, devops_dataops, educator</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_ViftH"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Github Copilot | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - sys_admin, devops_dataops, scientific_researcher, designer, educator</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_cDZIO"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Notion AI | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - sys_admin, scientific_researcher, designer</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_ATbKO"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 50% |
# | Github Copilot, ChatGPT | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - scientific_researcher, educator</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="ai_tools_by_prog_skills_in_role_bt859"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Google Bard, ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - sys_admin, devops_dataops, scientific_researcher, designer</em></p>
#     <br/>
# </center>

# %%
md_group_table(
    "table_programming_skills_in_role",
    df,
    "role",
    "prog_skills_in_role",
    "Use AI tools by programming skills in role.",
)
# Out:
# <center>
#     <a id="table_programming_skills_in_role_rSpTB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops, scientific_researcher | 50% |
# | scientific_researcher | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_hUjX5"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops, designer | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - desktop_apps, qa_testing, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_pk6Jk"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops, scientific_researcher | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_arch</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_OSvyE"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - desktop_apps, db_admin, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_GdNJ1"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_bFBKg"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, full_stack_dev, desktop_apps, db_admin, proj_lead, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_9wUcA"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops, scientific_researcher | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, desktop_apps, db_admin, dev_ops, sre</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_tlhbK"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 27% |
# | devops_dataops | 18% |
# | sys_admin, devops_dataops | 11% |
# | educator | 9% |
# | sys_admin, educator | 6% |
# | designer | 6% |
# | devops_dataops, designer | 4% |
# | sys_admin, designer | 4% |
# | scientific_researcher, designer, educator | 2% |
# | sys_admin, devops_dataops, scientific_researcher, designer, educator | 2% |
# | sys_admin, scientific_researcher, designer | 2% |
# | scientific_researcher | 2% |
# | sys_admin, devops_dataops, designer | 2% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_EkS9i"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_mnv5F"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 54% |
# | sys_admin | 22% |
# | devops_dataops, scientific_researcher | 9% |
# | designer | 4% |
# | sys_admin, devops_dataops, scientific_researcher | 4% |
# | sys_admin, devops_dataops | 4% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_mpgvB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 50% |
# | sys_admin | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_WJvxf"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, desktop_apps, db_admin, data_analyst, data_eng, data_sci, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_T4RhJ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops, scientific_researcher | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - it</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_r7e5R"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 75% |
# | sys_admin, scientific_researcher | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_2nPwQ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - frontend_dev, game_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_Tpwsh"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 33% |
# | educator | 16% |
# | sys_admin, educator | 16% |
# | sys_admin, devops_dataops | 16% |
# | sys_admin, devops_dataops, scientific_researcher, designer | 16% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_N2KPa"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, mobile_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_j3C4n"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 75% |
# | sys_admin, devops_dataops | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_h7SQq"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_HyceL"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 50% |
# | sys_admin, devops_dataops | 20% |
# | designer | 20% |
# | sys_admin, designer | 10% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_RUCP1"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 40% |
# | sys_admin | 40% |
# | sys_admin, devops_dataops | 20% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_rLmTR"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 33% |
# | devops_dataops, scientific_researcher | 33% |
# | sys_admin | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - data_analyst, data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_0RmA2"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - support_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_pwqGO"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | designer | 50% |
# | sys_admin | 25% |
# | sys_admin, scientific_researcher | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_y9Vma"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | designer | 75% |
# | sys_admin | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - frontend_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_cC7P3"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, proj_lead, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_V0yPI"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | designer | 33% |
# | sys_admin | 33% |
# | devops_dataops | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_SCWTB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 33% |
# | sys_admin, devops_dataops, educator | 33% |
# | sys_admin, devops_dataops | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_SFVj3"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - data_eng, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_RU5QK"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, scientific_researcher, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, qa_testing, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_wkFic"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 50% |
# | sys_admin | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, qa_testing</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_nJGcM"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, desktop_apps, qa_testing, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_1CKJB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_O58tM"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, designer | 25% |
# | educator | 25% |
# | devops_dataops | 25% |
# | sys_admin | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - qa_testing</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_Q1gxl"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, dev_ops, sys_arch</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_N2xfF"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, desktop_apps, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_WGzQb"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, designer | 50% |
# | sys_admin | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_rxJca"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - frontend_dev, mobile_dev, qa_testing</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_G3sGm"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, full_stack_dev, desktop_apps, qa_testing, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_JXpxs"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, db_admin, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_TzBC8"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | designer | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - frontend_dev, full_stack_dev, qa_testing, db_admin, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_qnYf7"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 50% |
# | educator | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_AE85r"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, scientific_researcher | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - qa_testing, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_532Xp"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, db_admin, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_21zJn"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | scientific_researcher | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - data_sci, ml_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_ocADx"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 25% |
# | sys_admin | 25% |
# | sys_admin, designer | 25% |
# | devops_dataops, designer | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_tR1G7"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, mobile_dev, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_tu2KG"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, embedded_sys_dev, desktop_apps, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_M7s8U"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, embedded_sys_dev, db_admin, proj_lead, data_analyst, data_eng, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_hJLOT"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops, scientific_researcher | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - data_sci</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_mFKbA"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 50% |
# | sys_admin | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, mobile_dev, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_0Ty4u"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, scientific_researcher | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, qa_testing, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_EMSkH"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - solution_arch</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_nlQCV"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 80% |
# | sys_admin, devops_dataops, scientific_researcher | 20% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_KMoAf"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | designer | 50% |
# | sys_admin, devops_dataops, designer | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_Th2MK"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, full_stack_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_ZQ5yN"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 50% |
# | sys_admin, devops_dataops | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_IZrDE"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, scientific_researcher, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, qa_testing, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_539u7"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - software_arch</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_xVnxa"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | designer | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - game_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_X2B6A"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - frontend_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_AYSM5"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, mobile_dev, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_1mqdN"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_pvpjb"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, full_stack_dev, mobile_dev, embedded_sys_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_SO1Xi"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - proj_lead, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_ClYSs"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, embedded_sys_dev, desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_i8p3x"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, mobile_dev, db_admin, proj_lead, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_ziq07"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_TsoEJ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, desktop_apps, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_DXXOY"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, designer | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - qa_testing, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_FB588"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 50% |
# | scientific_researcher | 25% |
# | devops_dataops | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_vCgRL"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, scientific_researcher, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - db_admin, proj_lead, data_analyst, data_eng, data_sci, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_xWvvq"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - it_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_XVkdw"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_KmcYZ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_5NTHC"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, designer | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, embedded_sys_dev, desktop_apps, db_admin, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_ZyqOg"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - frontend_dev, mobile_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_1Qbaj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - desktop_apps, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_N2JNs"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - db_admin, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_b2K9a"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - desktop_apps, qa_testing, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_dhusT"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, embedded_sys_dev, desktop_apps, proj_lead, data_analyst, ux_ui, dba</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_P24Te"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, qa_testing, db_admin, proj_lead, data_analyst, data_eng, api_rest</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_tWHOg"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - tableau_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_Kc3e6"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 50% |
# | sys_admin, devops_dataops | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_F37H8"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops, scientific_researcher | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, db_admin, proj_lead, data_eng, data_sci, dev_ops, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_WqXx0"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, cloud_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_ykVGI"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, designer | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, db_admin, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_NunP1"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, full_stack_dev, platform_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_pIXBL"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - proj_lead, data_analyst, data_eng, data_sci</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_nlYXd"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | designer | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - frontend_dev, full_stack_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_1WlPi"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | scientific_researcher, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, team_lead </em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_ZAn2R"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, full_stack_dev, desktop_apps, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_iasLv"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | designer | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - frontend_dev, data_analyst, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_xnJ5Y"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 75% |
# | sys_admin, devops_dataops | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_0VNug"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | scientific_researcher | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - data_analyst, data_eng, data_sci, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_j8Km7"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | designer | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_R4G5B"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | scientific_researcher, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - data_analyst, data_sci</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_tMIQu"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, qa_testing, proj_lead, dev_ops, ux_ui, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_3aeJ3"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, designer | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, desktop_apps, db_admin, data_analyst, data_eng, data_sci, dev_ops, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_6laWL"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, embedded_sys_dev, proj_lead, dev_ops, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_LRnIq"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, embedded_sys_dev, desktop_apps, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_14EgA"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, designer | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - quality_analyst </em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_6RfB0"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, game_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_8yxtt"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, data_eng, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_6aQGT"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, data_analyst, data_eng</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_6xpsg"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | scientific_researcher | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - frontend_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_6yht2"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, mobile_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_RO710"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, mobile_dev, desktop_apps</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_1WGkT"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_5TZ9Y"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, mobile_dev, desktop_apps, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_PDWHs"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | designer | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - frontend_dev, data_eng, data_sci</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_8u8tb"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, db_admin, ux_ui</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_FKs1J"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, desktop_apps, db_admin, data_eng, data_sci, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_PLuWd"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, db_admin, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_EA6q8"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, db_admin, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_LWsgQ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, data_analyst</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_5mrmG"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, embedded_sys_dev, proj_lead, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_Tl1B1"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - it_auditor</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_BpfWM"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, scientific_researcher, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, full_stack_dev, desktop_apps, data_analyst, ai_specialist</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_xrs8P"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - full_stack_dev, mobile_dev, db_admin, proj_lead, dev_ops</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_GltlV"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops, educator | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, platform_eng </em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_hE8wS"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, desktop_apps, qa_testing, db_admin, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_2xEUw"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, frontend_dev, full_stack_dev, proj_lead</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_8d3ts"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, full_stack_dev</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_INRbx"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - data_analyst, data_eng, data_sci</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_UX47s"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - backend_dev, full_stack_dev, desktop_apps, db_admin</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="table_programming_skills_in_role_0ApCm"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | sys_admin, devops_dataops | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Use AI tools by programming skills in role. - db_admin, dev_ops</em></p>
#     <br/>
# </center>

# %% [markdown]
# ## AI TOOLS - code_for_job

# %%
md_group_table(
    "code_for_job_vs_ai", df, "use_AI_tools", "code_for_job", "Code for job vs Use AI"
)
# Out:
# <center>
#     <a id="code_for_job_vs_ai_EMRmy"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 89% |
# | No | 10% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_rgHXl"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 80% |
# | No | 20% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_bPlzL"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 92% |
# | No | 7% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Github Copilot, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_pYuZ6"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Google Bard, Google Geminis</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_L3VU1"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 90% |
# | No | 9% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_UOffY"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Google Bard, ChatGPT, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_0y6ae"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Github Copilot, Notion AI, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_WpiXk"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 84% |
# | No | 15% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Google Bard, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_weCE4"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 87% |
# | No | 12% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_QrwGb"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_jrt4e"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Google Bard, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_uOquX"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Codeium</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_E7jBG"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - AiDE</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_jx58V"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Genesis, Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_1Gp4T"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 88% |
# | No | 11% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_gWtpB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Bing AI, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_qoIFV"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Google Bard, Github Copilot, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_loJJm"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Bing AI, ChatGPT, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_jRgt4"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Google Bard, CODEGEEX</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_eyTg7"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Google Bard, Github Copilot, ChatGPT, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_ioSzB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Github Copilot, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_exe4D"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Claude.ai</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_acnYF"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Github Copilot, TabNine</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_f1FDE"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_iuSDm"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Github Copilot, IntelliJ Assistant </em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_FBncN"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 83% |
# | No | 16% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Bing AI, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_3Gjcj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, AWS CodeWhisperer, Github Copilot, Notion AI, Bing AI, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_X57eh"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Microsoft Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_B8WF5"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Google Bard, Bing AI, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_KOBv9"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Github Copilot, Notion AI, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_kQVdz"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_zAR18"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Github Copilot, Notion AI, AWS CodeWhisperer</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_lBBti"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Google Bard, ChatGPT, Notion AI, Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_0afY2"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Github Copilot, AWS CodeWhisperer, ChatGPT, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_kB9oO"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Unity Muse</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_cyD3N"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Bing AI, ChatGPT, AWS CodeWhisperer, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_qhEjC"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Github Copilot, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_oG6ra"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Google Bard, Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_b2rWS"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Github Copilot, Notion AI, Google Bard, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_zZSbt"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Github Copilot, ChatGPT, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_NIjYn"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Notion AI, Github Copilot, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_p8H5D"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Bing AI, Github Copilot, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_UMmPl"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_SmKau"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - WolframAlpha, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_ygFsZ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Google Bard, ChatGPT, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_XqHNe"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Github Copilot, WolframAlpha</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_EfiNN"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Notion AI, ChatGPT, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_C0pPO"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Bing AI, ChatGPT, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_U6p7O"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Bing AI, AWS CodeWhisperer, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_K4fve"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Codeium</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_ks3Cj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Bing AI, Google Bard, ChatGPT, WolframAlpha, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_BsvpM"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Claude</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_MUYNY"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Notion AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_kU07Y"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_khF66"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - ChatGPT, Google Bard, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_iXl5G"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - WolframAlpha, ChatGPT, Claude Ai</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_pdLUj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - WolframAlpha, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_aI3W7"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Codium AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_lCC9B"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Google Bard, Bing AI, ChatGPT, Claude.ai</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="code_for_job_vs_ai_vZNr8"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Yes | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Code for job vs Use AI - Talkai</em></p>
#     <br/>
# </center>

# %% [markdown]
# ## AI TOOLS - IT_exp

# %%
md_group_table(
    "IT_exp_vs_use_ai", df, "use_AI_tools", "IT_exp", "IT experiece vs Use AI"
)
# Out:
# <center>
#     <a id="IT_exp_vs_use_ai_bE4C0"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 24% |
# | 10_12 years | 20% |
# | 3_5 years | 17% |
# | 18_25 years | 10% |
# | 13_17 years | 9% |
# | 1_2 years | 7% |
# | 26+ years | 5% |
# | <1 year | 4% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_cb0KF"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 3_5 years | 30% |
# | 10_12 years | 30% |
# | 13_17 years | 20% |
# | 1_2 years | 20% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_AcuZU"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 10_12 years | 30% |
# | 3_5 years | 26% |
# | 6_9 years | 15% |
# | 1_2 years | 11% |
# | 26+ years | 3% |
# | 13_17 years | 3% |
# | <1 year | 3% |
# | 18_25 years | 3% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Github Copilot, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_kuiuB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 26+ years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Google Bard, Google Geminis</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_h1Ayl"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 10_12 years | 18% |
# | 13_17 years | 18% |
# | 6_9 years | 18% |
# | <1 year | 15% |
# | 3_5 years | 12% |
# | 18_25 years | 9% |
# | 1_2 years | 6% |
# | 26+ years | 3% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_rjsHs"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 10_12 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Google Bard, ChatGPT, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_3kXW9"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 3_5 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Github Copilot, Notion AI, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_H9mqG"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 30% |
# | 3_5 years | 15% |
# | 13_17 years | 15% |
# | 1_2 years | 15% |
# | <1 year | 7% |
# | 18_25 years | 7% |
# | 10_12 years | 7% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Google Bard, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_EIgi2"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 37% |
# | 3_5 years | 12% |
# | 13_17 years | 12% |
# | <1 year | 12% |
# | 10_12 years | 12% |
# | 26+ years | 12% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_Drufm"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 66% |
# | 13_17 years | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_E24TA"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Google Bard, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_HThu1"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 13_17 years | 66% |
# | 10_12 years | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Codeium</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_on2sl"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - AiDE</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_o0LRe"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 10_12 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Genesis, Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_2vcBZ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 66% |
# | 3_5 years | 22% |
# | 26+ years | 11% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_TcFFv"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 3_5 years | 50% |
# | <1 year | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Bing AI, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_UyIJO"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 10_12 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Google Bard, Github Copilot, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_Fw5XB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Bing AI, ChatGPT, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_Blnaz"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Google Bard, CODEGEEX</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_5XQjQ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 10_12 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Google Bard, Github Copilot, ChatGPT, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_kXygZ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 18_25 years | 50% |
# | 10_12 years | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Github Copilot, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_W9GZW"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 1_2 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Claude.ai</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_Q4Q7N"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 1_2 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Github Copilot, TabNine</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_9ek5P"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 3_5 years | 50% |
# | 13_17 years | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_PYJqD"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 13_17 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Github Copilot, IntelliJ Assistant </em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_AOdlJ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 13_17 years | 33% |
# | 18_25 years | 33% |
# | 3_5 years | 16% |
# | 1_2 years | 16% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Bing AI, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_zxzk0"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 10_12 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, AWS CodeWhisperer, Github Copilot, Notion AI, Bing AI, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_Q6ZiE"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 10_12 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Microsoft Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_H5HIf"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 3_5 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Google Bard, Bing AI, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_fr9Ci"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 13_17 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Github Copilot, Notion AI, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_jXtPT"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 18_25 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_lQrTw"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 18_25 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Github Copilot, Notion AI, AWS CodeWhisperer</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_EzwXq"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 13_17 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Google Bard, ChatGPT, Notion AI, Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_EEQ4f"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 3_5 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Github Copilot, AWS CodeWhisperer, ChatGPT, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_5oV6Y"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 3_5 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Unity Muse</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_TxW6A"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Bing AI, ChatGPT, AWS CodeWhisperer, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_bOaoQ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 10_12 years | 50% |
# | 1_2 years | 25% |
# | 3_5 years | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Github Copilot, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_EuNL4"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 26+ years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Google Bard, Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_MlFJi"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Github Copilot, Notion AI, Google Bard, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_YQ2uo"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 10_12 years | 50% |
# | 3_5 years | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Github Copilot, ChatGPT, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_sLPJA"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 10_12 years | 50% |
# | 6_9 years | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Notion AI, Github Copilot, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_CYYzR"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 1_2 years | 50% |
# | 3_5 years | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Bing AI, Github Copilot, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_vK4wX"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 18_25 years | 50% |
# | 10_12 years | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_K15A3"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | <1 year | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - WolframAlpha, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_dciNX"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 3_5 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Google Bard, ChatGPT, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_Ulkzx"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Github Copilot, WolframAlpha</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_CoYMh"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 50% |
# | 10_12 years | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Notion AI, ChatGPT, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_A5dsp"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 3_5 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Bing AI, ChatGPT, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_IgjQ9"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 1_2 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Bing AI, AWS CodeWhisperer, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_E5YHE"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | <1 year | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Codeium</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_87RRr"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | <1 year | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Bing AI, Google Bard, ChatGPT, WolframAlpha, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_X7Fdj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Claude</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_IOlko"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 3_5 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Notion AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_dgtwu"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 10_12 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_sL9UM"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 50% |
# | 10_12 years | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - ChatGPT, Google Bard, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_3gjmi"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 3_5 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - WolframAlpha, ChatGPT, Claude Ai</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_nkU22"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 18_25 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - WolframAlpha, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_YSQAG"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 3_5 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Codium AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_9CPBn"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 3_5 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Google Bard, Bing AI, ChatGPT, Claude.ai</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_use_ai_jAR7T"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | 6_9 years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>IT experiece vs Use AI - Talkai</em></p>
#     <br/>
# </center>

# %% [markdown]
# ## AI TOOLS - assigned_seniority

# %%
md_group_table(
    "assigned_seniority_vs_ai_use",
    df,
    "use_AI_tools",
    "assigned_seniority",
    "Assigned Seniority vs Use AI",
)
# Out:
# <center>
#     <a id="assigned_seniority_vs_ai_use_O63Pi"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 39% |
# | Mid-senior | 20% |
# | Junior | 13% |
# | No aplica a mi lugar de trabajo | 13% |
# | Staff | 5% |
# | Principal | 5% |
# | Trainee | 0% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_veo70"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Junior | 30% |
# | Senior | 20% |
# | Mid-senior | 20% |
# | Trainee | 10% |
# | No aplica a mi lugar de trabajo | 10% |
# | Staff | 10% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_Pb499"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 38% |
# | Mid-senior | 19% |
# | Junior | 19% |
# | Principal | 7% |
# | No aplica a mi lugar de trabajo | 7% |
# | Staff | 3% |
# | Trainee | 3% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Github Copilot, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_SySQe"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Google Bard, Google Geminis</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_vBN4A"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 45% |
# | Mid-senior | 21% |
# | Junior | 18% |
# | No aplica a mi lugar de trabajo | 9% |
# | Principal | 3% |
# | Trainee | 3% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_KC9g6"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Google Bard, ChatGPT, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_vGm8P"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Mid-senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Github Copilot, Notion AI, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_YYnjr"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 46% |
# | Mid-senior | 30% |
# | Junior | 7% |
# | No aplica a mi lugar de trabajo | 7% |
# | Principal | 7% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Google Bard, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_zfJka"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Mid-senior | 37% |
# | Senior | 25% |
# | No aplica a mi lugar de trabajo | 25% |
# | Principal | 12% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_LKGGS"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No aplica a mi lugar de trabajo | 66% |
# | Junior | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_6Kqch"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Google Bard, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_4PTda"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 66% |
# | No aplica a mi lugar de trabajo | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Codeium</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_G4gtn"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - AiDE</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_oKTld"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Mid-senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Genesis, Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_gP7fX"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 55% |
# | No aplica a mi lugar de trabajo | 11% |
# | Principal | 11% |
# | Mid-senior | 11% |
# | Junior | 11% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_KKgli"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No aplica a mi lugar de trabajo | 50% |
# | Junior | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Bing AI, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_scIft"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Google Bard, Github Copilot, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_ziPxt"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Bing AI, ChatGPT, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_zgzFu"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No aplica a mi lugar de trabajo | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Google Bard, CODEGEEX</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_Nmp2h"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Google Bard, Github Copilot, ChatGPT, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_0fwZ5"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 50% |
# | Mid-senior | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Github Copilot, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_3o6Gj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No aplica a mi lugar de trabajo | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Claude.ai</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_keZOX"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Junior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Github Copilot, TabNine</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_oX42r"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No aplica a mi lugar de trabajo | 50% |
# | Senior | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_1qGR9"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Github Copilot, IntelliJ Assistant </em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_KqEqB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 50% |
# | No aplica a mi lugar de trabajo | 16% |
# | Junior | 16% |
# | Principal | 16% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Bing AI, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_cLjgX"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, AWS CodeWhisperer, Github Copilot, Notion AI, Bing AI, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_PKJgm"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Principal | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Microsoft Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_4h6sb"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Google Bard, Bing AI, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_IqAuw"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Github Copilot, Notion AI, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_W854N"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_vvam3"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Github Copilot, Notion AI, AWS CodeWhisperer</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_U9vyD"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Google Bard, ChatGPT, Notion AI, Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_ediBV"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Github Copilot, AWS CodeWhisperer, ChatGPT, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_ud0CA"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No aplica a mi lugar de trabajo | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Unity Muse</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_r4WAg"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Mid-senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Bing AI, ChatGPT, AWS CodeWhisperer, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_sN3IW"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 50% |
# | Junior | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Github Copilot, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_hS6o0"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Google Bard, Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_7PStQ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No aplica a mi lugar de trabajo | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Github Copilot, Notion AI, Google Bard, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_skfoV"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 50% |
# | Junior | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Github Copilot, ChatGPT, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_lIQus"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Notion AI, Github Copilot, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_y4g3k"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Junior | 50% |
# | Mid-senior | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Bing AI, Github Copilot, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_r35Pl"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_WV51M"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - WolframAlpha, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_gF7y5"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Mid-senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Google Bard, ChatGPT, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_WZRTm"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Github Copilot, WolframAlpha</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_QG3kf"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Junior | 50% |
# | Senior | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Notion AI, ChatGPT, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_k9SXV"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Trainee | 50% |
# | Mid-senior | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Bing AI, ChatGPT, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_816ji"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Junior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Bing AI, AWS CodeWhisperer, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_f82zE"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Junior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Codeium</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_KoC9r"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Junior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Bing AI, Google Bard, ChatGPT, WolframAlpha, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_NPwMN"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Mid-senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Claude</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_18ofg"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No aplica a mi lugar de trabajo | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Notion AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_QeEZX"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Mid-senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_e33fj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Mid-senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - ChatGPT, Google Bard, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_YjqJV"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No aplica a mi lugar de trabajo | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - WolframAlpha, ChatGPT, Claude Ai</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_LVszG"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Staff | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - WolframAlpha, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_Z3H82"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Mid-senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Codium AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_ECjfl"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Mid-senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Google Bard, Bing AI, ChatGPT, Claude.ai</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="assigned_seniority_vs_ai_use_12sX8"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Mid-senior | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Assigned Seniority vs Use AI - Talkai</em></p>
#     <br/>
# </center>

# %% [markdown]
# ## AI TOOLS - self_assessed_seniority

# %%
md_group_table(
    "self_assessed_seniority_vs_use_ai",
    df,
    "self_assessed_seniority",
    "use_AI_tools",
    "Self assesed seniority vs Use AI",
)
# Out:
# <center>
#     <a id="self_assessed_seniority_vs_use_ai_DmtLB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 40% |
# | Github Copilot, ChatGPT | 13% |
# | ChatGPT, Github Copilot | 11% |
# | ChatGPT, Bing AI | 6% |
# | Google Bard, ChatGPT | 6% |
# | Bing AI | 2% |
# | ChatGPT, Github Copilot, TabNine | 2% |
# | ChatGPT, Github Copilot, Google Bard | 2% |
# | Bing AI, ChatGPT | 2% |
# | Bing AI, ChatGPT, Github Copilot | 2% |
# | Bing AI, AWS CodeWhisperer, ChatGPT | 2% |
# | ChatGPT, Codeium | 2% |
# | Bing AI, Google Bard, ChatGPT, WolframAlpha, Notion AI | 2% |
# | Google Bard, Bing AI, ChatGPT, Claude.ai | 2% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Self assesed seniority vs Use AI - Junior</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="self_assessed_seniority_vs_use_ai_QZAx0"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 48% |
# | ChatGPT, Github Copilot | 9% |
# | Github Copilot, ChatGPT | 8% |
# | Google Bard, ChatGPT | 3% |
# | Github Copilot | 3% |
# | ChatGPT, Google Bard | 2% |
# | Codeium | 2% |
# | ChatGPT, Bing AI | 2% |
# | Github Copilot, Bing AI | 1% |
# | Bing AI, ChatGPT | 1% |
# | Github Copilot, ChatGPT, Google Bard | 1% |
# | ChatGPT, Google Bard, Github Copilot | 0% |
# | Google Bard, ChatGPT, Notion AI, Bing AI, Github Copilot | 0% |
# | ChatGPT, Google Bard, Bing AI | 0% |
# | Notion AI, ChatGPT, Bing AI | 0% |
# | WolframAlpha, ChatGPT | 0% |
# | Notion AI | 0% |
# | Google Bard | 0% |
# | Notion AI, Github Copilot, ChatGPT | 0% |
# | ChatGPT, Google Bard, Bing AI, Github Copilot | 0% |
# | Github Copilot, Notion AI, ChatGPT | 0% |
# | Github Copilot, Notion AI, AWS CodeWhisperer | 0% |
# | Google Bard, ChatGPT, Notion AI | 0% |
# | ChatGPT, AWS CodeWhisperer, Github Copilot, Notion AI, Bing AI, Google Bard | 0% |
# | Github Copilot, IntelliJ Assistant  | 0% |
# | Google Bard, Google Geminis | 0% |
# | Google Bard, Github Copilot, ChatGPT, Notion AI | 0% |
# | Bing AI, ChatGPT, Notion AI | 0% |
# | ChatGPT, Google Bard, Github Copilot, Bing AI | 0% |
# | AiDE | 0% |
# | ChatGPT, Github Copilot, Google Bard | 0% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Self assesed seniority vs Use AI - Senior</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="self_assessed_seniority_vs_use_ai_07amG"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 60% |
# | Bing AI | 8% |
# | Github Copilot | 8% |
# | ChatGPT, Github Copilot | 4% |
# | Microsoft Copilot | 4% |
# | Bing AI, Github Copilot | 4% |
# | Bing AI, ChatGPT | 4% |
# | ChatGPT, Bing AI | 4% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Self assesed seniority vs Use AI - Principal</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="self_assessed_seniority_vs_use_ai_NTk2N"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 47% |
# | ChatGPT, Github Copilot | 11% |
# | Github Copilot, ChatGPT | 5% |
# | ChatGPT, Google Bard | 3% |
# | Github Copilot | 2% |
# | Google Bard, ChatGPT | 2% |
# | ChatGPT, Github Copilot, Google Bard | 1% |
# | Bing AI, Github Copilot, ChatGPT | 1% |
# | ChatGPT, Genesis, Copilot | 0% |
# | Github Copilot, WolframAlpha | 0% |
# | WolframAlpha, ChatGPT, Claude Ai | 0% |
# | Notion AI | 0% |
# | ChatGPT, Google Bard, Bing AI | 0% |
# | ChatGPT, Bing AI, Github Copilot | 0% |
# | ChatGPT, Notion AI, Github Copilot | 0% |
# | Bing AI, ChatGPT, Github Copilot | 0% |
# | Claude | 0% |
# | Notion AI, ChatGPT, Bing AI | 0% |
# | Google Bard, ChatGPT, Bing AI | 0% |
# | Notion AI, Github Copilot, ChatGPT | 0% |
# | ChatGPT, Bing AI, Google Bard | 0% |
# | Github Copilot, Notion AI, Google Bard, ChatGPT | 0% |
# | ChatGPT, Github Copilot, Notion AI, Bing AI | 0% |
# | ChatGPT, Bing AI | 0% |
# | Bing AI, ChatGPT, AWS CodeWhisperer, Google Bard | 0% |
# | ChatGPT, Unity Muse | 0% |
# | Github Copilot, AWS CodeWhisperer, ChatGPT, Google Bard | 0% |
# | Google Bard, Bing AI, ChatGPT | 0% |
# | Codium AI | 0% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Self assesed seniority vs Use AI - Mid-senior</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="self_assessed_seniority_vs_use_ai_XQsnL"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 28% |
# | ChatGPT, Bing AI | 14% |
# | ChatGPT, Claude.ai | 14% |
# | ChatGPT, Github Copilot | 14% |
# | Bing AI, ChatGPT | 14% |
# | Github Copilot, ChatGPT | 14% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Self assesed seniority vs Use AI - Trainee</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="self_assessed_seniority_vs_use_ai_23qbn"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 46% |
# | Google Bard, ChatGPT | 15% |
# | ChatGPT, Bing AI, Google Bard | 7% |
# | ChatGPT, Google Bard, CODEGEEX | 7% |
# | Google Bard | 7% |
# | ChatGPT, Google Bard | 7% |
# | Talkai | 7% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Self assesed seniority vs Use AI - Desconozco</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="self_assessed_seniority_vs_use_ai_B9S3x"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 53% |
# | Github Copilot, ChatGPT | 15% |
# | ChatGPT, Bing AI | 7% |
# | Bing AI, ChatGPT | 7% |
# | ChatGPT, Github Copilot | 7% |
# | WolframAlpha, Github Copilot | 7% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Self assesed seniority vs Use AI - Staff</em></p>
#     <br/>
# </center>

# %% [markdown]
# ## AI TOOLS - gender

# %%
md_group_table("gender_vs_use_ai", df, "use_AI_tools", "gender", "Gender vs Use AI")
# Out:
# <center>
#     <a id="gender_vs_use_ai_ISFZ8"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 86% |
# | female | 12% |
# | prefer_not_to_say | 1% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_xiMb3"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 90% |
# | female | 10% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_AYtAu"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 96% |
# | female | 3% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Github Copilot, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_JuW9K"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Google Bard, Google Geminis</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_v166e"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 93% |
# | female | 6% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_KRYP4"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | female | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Google Bard, ChatGPT, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_5IpzL"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Github Copilot, Notion AI, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_RvABe"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 92% |
# | female | 7% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Google Bard, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_iY4fo"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_8bRZ1"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 66% |
# | female | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_Ln9y5"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Google Bard, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_IZyvn"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Codeium</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_pMVmG"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - AiDE</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_yFHuQ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Genesis, Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_za5n3"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_rLgUq"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Bing AI, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_iu6d3"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Google Bard, Github Copilot, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_L9gjy"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | female | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Bing AI, ChatGPT, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_Fp5t3"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Google Bard, CODEGEEX</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_j1EOi"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Google Bard, Github Copilot, ChatGPT, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_yJTUs"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Github Copilot, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_x6Z3i"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | female | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Claude.ai</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_6HCM5"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Github Copilot, TabNine</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_eBWgS"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_oOoFB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Github Copilot, IntelliJ Assistant </em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_ZkKId"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 83% |
# | female | 16% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Bing AI, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_hTOxC"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, AWS CodeWhisperer, Github Copilot, Notion AI, Bing AI, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_bxDA2"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Microsoft Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_oxeYh"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Google Bard, Bing AI, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_EV50G"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Github Copilot, Notion AI, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_nY46C"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_uw4Ve"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Github Copilot, Notion AI, AWS CodeWhisperer</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_mBb6s"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Google Bard, ChatGPT, Notion AI, Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_wbZVz"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Github Copilot, AWS CodeWhisperer, ChatGPT, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_peyv1"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Unity Muse</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_rGmj7"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Bing AI, ChatGPT, AWS CodeWhisperer, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_LhoCA"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 75% |
# | female | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Github Copilot, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_FPPht"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Google Bard, Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_SoSIX"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Github Copilot, Notion AI, Google Bard, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_LUZI3"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 50% |
# | female | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Github Copilot, ChatGPT, Google Bard</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_AWGNh"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Notion AI, Github Copilot, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_2njdG"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Bing AI, Github Copilot, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_p3qOf"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_YflZ2"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - WolframAlpha, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_jfj1j"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Google Bard, ChatGPT, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_z3OV1"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Github Copilot, WolframAlpha</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_ov6rp"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Notion AI, ChatGPT, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_6CD1s"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Bing AI, ChatGPT, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_JgG4h"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | female | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Bing AI, AWS CodeWhisperer, ChatGPT</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_keRKt"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Codeium</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_DltDN"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Bing AI, Google Bard, ChatGPT, WolframAlpha, Notion AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_OFIlG"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Claude</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_SqQmT"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Notion AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_hlGfJ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Bing AI, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_acr4O"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 50% |
# | female | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - ChatGPT, Google Bard, Bing AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_jbQKd"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - WolframAlpha, ChatGPT, Claude Ai</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_8Ax8A"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - WolframAlpha, Github Copilot</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_JAQY6"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Codium AI</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_qa3RN"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | male | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Google Bard, Bing AI, ChatGPT, Claude.ai</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="gender_vs_use_ai_Tm4zC"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | female | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Gender vs Use AI - Talkai</em></p>
#     <br/>
# </center>

# %% [markdown]
# ## AI TOOLS - age

# %%
md_group_table("age_vs_use_ai", df, "age", "use_AI_tools", "Age vs Use AI")
# Out:
# <center>
#     <a id="age_vs_use_ai_aUm75"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 60% |
# | ChatGPT, Github Copilot | 7% |
# | Github Copilot, ChatGPT | 5% |
# | Google Bard, ChatGPT | 5% |
# | Bing AI, ChatGPT | 5% |
# | Codeium | 2% |
# | Github Copilot | 2% |
# | Github Copilot, Notion AI, ChatGPT | 2% |
# | Google Bard | 2% |
# | Notion AI | 2% |
# | WolframAlpha, Github Copilot | 2% |
# | ChatGPT, Bing AI | 2% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Age vs Use AI - 40_44 years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="age_vs_use_ai_PU8gz"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 41% |
# | ChatGPT, Github Copilot | 8% |
# | Github Copilot, ChatGPT | 8% |
# | Google Bard, ChatGPT | 5% |
# | ChatGPT, Bing AI | 3% |
# | ChatGPT, Google Bard | 3% |
# | Github Copilot | 3% |
# | Bing AI, ChatGPT | 2% |
# | AiDE | 1% |
# | Github Copilot, ChatGPT, Google Bard | 1% |
# | WolframAlpha, ChatGPT, Claude Ai | 1% |
# | Notion AI | 1% |
# | ChatGPT, Notion AI, Github Copilot | 1% |
# | Claude | 1% |
# | ChatGPT, Codeium | 1% |
# | ChatGPT, Github Copilot, Google Bard | 1% |
# | Notion AI, ChatGPT, Bing AI | 1% |
# | WolframAlpha, ChatGPT | 1% |
# | ChatGPT, Google Bard, Github Copilot | 1% |
# | Bing AI, ChatGPT, AWS CodeWhisperer, Google Bard | 1% |
# | Github Copilot, AWS CodeWhisperer, ChatGPT, Google Bard | 1% |
# | Google Bard, Bing AI, ChatGPT | 1% |
# | ChatGPT, Github Copilot, Notion AI, Bing AI | 1% |
# | ChatGPT, Claude.ai | 1% |
# | Google Bard, Github Copilot, ChatGPT, Notion AI | 1% |
# | Bing AI | 1% |
# | Google Bard, Bing AI, ChatGPT, Claude.ai | 1% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Age vs Use AI - 25_29 years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="age_vs_use_ai_GjC5V"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 50% |
# | Github Copilot, ChatGPT | 20% |
# | ChatGPT, Github Copilot | 10% |
# | Github Copilot | 10% |
# | Bing AI | 10% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Age vs Use AI - 45_49 years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="age_vs_use_ai_1yVBK"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 48% |
# | ChatGPT, Github Copilot | 9% |
# | Github Copilot, ChatGPT | 3% |
# | Bing AI, ChatGPT | 3% |
# | ChatGPT, Google Bard | 3% |
# | Bing AI, ChatGPT, Notion AI | 1% |
# | Google Bard, ChatGPT, Notion AI, Bing AI, Github Copilot | 1% |
# | ChatGPT, Github Copilot, Google Bard | 1% |
# | Google Bard, ChatGPT | 1% |
# | ChatGPT, Genesis, Copilot | 1% |
# | Github Copilot, ChatGPT, Google Bard | 1% |
# | ChatGPT, Bing AI | 1% |
# | Github Copilot | 1% |
# | Github Copilot, Notion AI, AWS CodeWhisperer | 1% |
# | Bing AI | 1% |
# | Bing AI, Github Copilot | 1% |
# | Google Bard, Google Geminis | 1% |
# | Github Copilot, IntelliJ Assistant  | 1% |
# | Github Copilot, Bing AI | 1% |
# | Codeium | 1% |
# | ChatGPT, Bing AI, Google Bard | 1% |
# | Talkai | 1% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Age vs Use AI - 35_39 years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="age_vs_use_ai_xXCuo"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 50% |
# | ChatGPT, Google Bard | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Age vs Use AI - 60+ years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="age_vs_use_ai_biiOh"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 46% |
# | ChatGPT, Github Copilot | 11% |
# | Github Copilot, ChatGPT | 8% |
# | Google Bard, ChatGPT | 4% |
# | ChatGPT, Bing AI | 3% |
# | Github Copilot | 3% |
# | ChatGPT, Google Bard, Bing AI | 2% |
# | Github Copilot, WolframAlpha | 1% |
# | Codium AI | 1% |
# | ChatGPT, Bing AI, Github Copilot | 1% |
# | Bing AI, ChatGPT, Github Copilot | 1% |
# | Notion AI, ChatGPT, Bing AI | 1% |
# | Bing AI, Google Bard, ChatGPT, WolframAlpha, Notion AI | 1% |
# | Codeium | 1% |
# | ChatGPT, Google Bard | 1% |
# | ChatGPT, Github Copilot, Google Bard | 1% |
# | Notion AI, Github Copilot, ChatGPT | 1% |
# | Github Copilot, Notion AI, Google Bard, ChatGPT | 1% |
# | ChatGPT, Unity Muse | 1% |
# | Microsoft Copilot | 1% |
# | ChatGPT, AWS CodeWhisperer, Github Copilot, Notion AI, Bing AI, Google Bard | 1% |
# | Google Bard | 1% |
# | ChatGPT, Google Bard, CODEGEEX | 1% |
# | ChatGPT, Google Bard, Github Copilot, Bing AI | 1% |
# | Google Bard, ChatGPT, Notion AI | 1% |
# | Github Copilot, Bing AI | 1% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Age vs Use AI - 30_34 years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="age_vs_use_ai_f2hmf"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 45% |
# | Github Copilot, ChatGPT | 11% |
# | ChatGPT, Github Copilot | 11% |
# | ChatGPT, Bing AI | 4% |
# | Bing AI, Github Copilot, ChatGPT | 4% |
# | ChatGPT, Github Copilot, TabNine | 2% |
# | ChatGPT, Bing AI, Google Bard | 2% |
# | ChatGPT, Github Copilot, Google Bard | 2% |
# | Google Bard, ChatGPT | 2% |
# | ChatGPT, Google Bard | 2% |
# | Google Bard, ChatGPT, Bing AI | 2% |
# | Notion AI, Github Copilot, ChatGPT | 2% |
# | Bing AI, ChatGPT, Github Copilot | 2% |
# | Bing AI, AWS CodeWhisperer, ChatGPT | 2% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Age vs Use AI - 20_24 years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="age_vs_use_ai_jJq1t"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 75% |
# | ChatGPT, Github Copilot | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Age vs Use AI - 15_19 years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="age_vs_use_ai_lLKvB"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 50% |
# | ChatGPT, Google Bard, Bing AI, Github Copilot | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Age vs Use AI - 50_54 years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="age_vs_use_ai_HRrfw"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Age vs Use AI - 55_59 years</em></p>
#     <br/>
# </center>

# %% [markdown]
# ## AI TOOLS - monthly_salary

# %%
md_group_table(
    "monthly_salary_vs_use_ai",
    df,
    "monthly_salary",
    "use_AI_tools",
    "Monthly Salary vs Use AI",
)
# Out:
# <center>
#     <a id="monthly_salary_vs_use_ai_hU9lt"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 69% |
# | Github Copilot, ChatGPT | 7% |
# | Codeium | 3% |
# | Github Copilot | 3% |
# | ChatGPT, Github Copilot | 3% |
# | Github Copilot, ChatGPT, Google Bard | 3% |
# | ChatGPT, Google Bard | 3% |
# | Bing AI, ChatGPT | 3% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - 15M_18M</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="monthly_salary_vs_use_ai_NrSYH"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 57% |
# | Github Copilot, ChatGPT | 9% |
# | ChatGPT, Bing AI | 6% |
# | Bing AI | 3% |
# | Bing AI, ChatGPT, Notion AI | 3% |
# | ChatGPT, Bing AI, Google Bard | 3% |
# | ChatGPT, Github Copilot, Google Bard | 3% |
# | Google Bard, ChatGPT | 3% |
# | Bing AI, Github Copilot, ChatGPT | 3% |
# | Bing AI, ChatGPT, Github Copilot | 3% |
# | WolframAlpha, ChatGPT, Claude Ai | 3% |
# | Talkai | 3% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - 3.5M_5M</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="monthly_salary_vs_use_ai_DDFOP"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 35% |
# | Github Copilot, ChatGPT | 14% |
# | ChatGPT, Github Copilot, Notion AI, Bing AI | 7% |
# | ChatGPT, Bing AI | 7% |
# | Bing AI, Github Copilot | 7% |
# | Bing AI, AWS CodeWhisperer, ChatGPT | 7% |
# | Bing AI, ChatGPT | 7% |
# | Notion AI | 7% |
# | Github Copilot, Bing AI | 7% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - 18M_21M</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="monthly_salary_vs_use_ai_GLsjO"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT, Github Copilot | 16% |
# | ChatGPT | 16% |
# | Github Copilot, ChatGPT | 8% |
# | AiDE | 8% |
# | Github Copilot | 8% |
# | Github Copilot, IntelliJ Assistant  | 8% |
# | ChatGPT, Google Bard | 8% |
# | Google Bard, ChatGPT, Notion AI, Bing AI, Github Copilot | 8% |
# | Github Copilot, AWS CodeWhisperer, ChatGPT, Google Bard | 8% |
# | Notion AI, Github Copilot, ChatGPT | 8% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - 33M_40M</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="monthly_salary_vs_use_ai_W5FEa"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 57% |
# | Microsoft Copilot | 14% |
# | Github Copilot, WolframAlpha | 14% |
# | Github Copilot, ChatGPT | 14% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - 40M_50M</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="monthly_salary_vs_use_ai_3UqJV"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 45% |
# | ChatGPT, Github Copilot | 8% |
# | Github Copilot, ChatGPT | 8% |
# | Google Bard, ChatGPT | 5% |
# | ChatGPT, Google Bard | 5% |
# | Github Copilot | 5% |
# | Google Bard, Google Geminis | 2% |
# | ChatGPT, Google Bard, Github Copilot | 2% |
# | ChatGPT, Google Bard, CODEGEEX | 2% |
# | Bing AI | 2% |
# | Github Copilot, Bing AI | 2% |
# | ChatGPT, AWS CodeWhisperer, Github Copilot, Notion AI, Bing AI, Google Bard | 2% |
# | ChatGPT, Bing AI | 2% |
# | Notion AI | 2% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - 7M_9M</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="monthly_salary_vs_use_ai_evg00"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 46% |
# | Github Copilot, ChatGPT | 10% |
# | ChatGPT, Github Copilot | 10% |
# | ChatGPT, Google Bard | 6% |
# | Google Bard, ChatGPT | 4% |
# | ChatGPT, Bing AI | 4% |
# | Google Bard, ChatGPT, Notion AI | 2% |
# | ChatGPT, Google Bard, Github Copilot, Bing AI | 2% |
# | Google Bard, Github Copilot, ChatGPT, Notion AI | 2% |
# | Google Bard, Bing AI, ChatGPT | 2% |
# | Github Copilot, Notion AI, Google Bard, ChatGPT | 2% |
# | Google Bard | 2% |
# | Bing AI, Google Bard, ChatGPT, WolframAlpha, Notion AI | 2% |
# | Notion AI, ChatGPT, Bing AI | 2% |
# | ChatGPT, Bing AI, Github Copilot | 2% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - 9M_12M</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="monthly_salary_vs_use_ai_ZTMPj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 33% |
# | ChatGPT, Github Copilot | 25% |
# | Github Copilot, ChatGPT | 8% |
# | Github Copilot | 8% |
# | Bing AI, ChatGPT | 8% |
# | WolframAlpha, Github Copilot | 8% |
# | ChatGPT, Github Copilot, Google Bard | 8% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - 50M+</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="monthly_salary_vs_use_ai_2Ynru"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 69% |
# | ChatGPT, Github Copilot | 23% |
# | Github Copilot, Notion AI, ChatGPT | 7% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - 24M_27M</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="monthly_salary_vs_use_ai_IVzkF"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 66% |
# | ChatGPT, Bing AI | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - min_wage</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="monthly_salary_vs_use_ai_5fbsq"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 25% |
# | ChatGPT, Github Copilot | 18% |
# | Github Copilot, ChatGPT | 11% |
# | ChatGPT, Bing AI | 7% |
# | Google Bard, ChatGPT | 3% |
# | ChatGPT, Claude.ai | 3% |
# | ChatGPT, Github Copilot, TabNine | 3% |
# | Google Bard | 3% |
# | ChatGPT, Unity Muse | 3% |
# | ChatGPT, Google Bard | 3% |
# | WolframAlpha, ChatGPT | 3% |
# | ChatGPT, Codeium | 3% |
# | Bing AI | 3% |
# | Google Bard, Bing AI, ChatGPT, Claude.ai | 3% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - 2.55M_3.5M</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="monthly_salary_vs_use_ai_Buvkf"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 55% |
# | Google Bard, ChatGPT | 6% |
# | ChatGPT, Github Copilot | 6% |
# | Github Copilot, ChatGPT | 4% |
# | Github Copilot, ChatGPT, Google Bard | 2% |
# | ChatGPT, Notion AI, Github Copilot | 2% |
# | Claude | 2% |
# | ChatGPT, Github Copilot, Google Bard | 2% |
# | Bing AI, ChatGPT, Github Copilot | 2% |
# | Notion AI, ChatGPT, Bing AI | 2% |
# | ChatGPT, Bing AI | 2% |
# | Bing AI, ChatGPT | 2% |
# | ChatGPT, Genesis, Copilot | 2% |
# | Codeium | 2% |
# | ChatGPT, Bing AI, Google Bard | 2% |
# | Github Copilot | 2% |
# | Bing AI, Github Copilot, ChatGPT | 2% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - 5M_7M</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="monthly_salary_vs_use_ai_07HfC"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 41% |
# | ChatGPT, Github Copilot | 17% |
# | Github Copilot, ChatGPT | 6% |
# | Google Bard, ChatGPT | 6% |
# | ChatGPT, Google Bard, Bing AI | 6% |
# | Github Copilot | 3% |
# | Bing AI, ChatGPT | 3% |
# | ChatGPT, Google Bard, Bing AI, Github Copilot | 3% |
# | Notion AI, Github Copilot, ChatGPT | 3% |
# | Codeium | 3% |
# | Codium AI | 3% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - 12M_15M</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="monthly_salary_vs_use_ai_fvU7Z"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 50% |
# | Github Copilot | 25% |
# | Bing AI, ChatGPT, AWS CodeWhisperer, Google Bard | 12% |
# | ChatGPT, Github Copilot, Google Bard | 12% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - 21M_24M</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="monthly_salary_vs_use_ai_vuXvs"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 44% |
# | Google Bard, ChatGPT | 22% |
# | Github Copilot, Notion AI, AWS CodeWhisperer | 11% |
# | Github Copilot, ChatGPT | 11% |
# | ChatGPT, Github Copilot | 11% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - 27M_33M</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="monthly_salary_vs_use_ai_QewRg"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | ChatGPT | 33% |
# | ChatGPT, Github Copilot | 33% |
# | Bing AI, ChatGPT | 16% |
# | Google Bard, ChatGPT, Bing AI | 16% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Monthly Salary vs Use AI - <min_wage</em></p>
#     <br/>
# </center>

# %% [markdown]
# # AI REPLACEMENT of DEVS

# %%
md_table(
    "ai_replace_devs",
    uniques_count_to_dataframe(df["AI_replace_dev"].value_counts()),
    "AI replacement of DEVs total count",
)
# Out:
#         <center>
#         <a id="ai_replace_devs_m81i2"></a>
#
#         | category           |   count |
# |:-------------------|--------:|
# | No                 |     253 |
# | maybe_in_10+_years |     127 |
# | Sí                 |      14 |
#
#         <p style="text-align: center;"><em>AI replacement of DEVs total count</em></p>
#         </center>
#         <br/>
#         <br/>

# %% [markdown]
# ## AI replacement vs. IT experience.

# %%
ai_replace_group = df.groupby("AI_replace_dev")

# %%
grouped_grid_barh_chart(
    ai_replace_group, "IT_exp", "AI replacement and IT experience.", 3, 1, "blue", 9
)

# %% [markdown]
# ## AI replacement by gender.

# %%
gender_gorups = df.groupby("gender")

# %%
grouped_grid_barh_chart(
    gender_gorups, "AI_replace_dev", "AI replacement by gender.", 3, 1, "blue", 8.5
)

# %% [markdown]
# ## AI replacement vs. work_mode

# %%
md_group_table(
    "work_mode_vs_AI_replace_dev",
    df,
    "work_mode",
    "AI_replace_dev",
    "Will AI replace devs? \n by work mode.",
)
# Out:
# <center>
#     <a id="work_mode_vs_AI_replace_dev_cw4jP"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 64% |
# | maybe_in_10+_years | 33% |
# | Sí | 1% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by work mode. - remote</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="work_mode_vs_AI_replace_dev_f6Pqz"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 63% |
# | maybe_in_10+_years | 33% |
# | Sí | 3% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by work mode. - onsite</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="work_mode_vs_AI_replace_dev_EwwtM"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 65% |
# | maybe_in_10+_years | 29% |
# | Sí | 5% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by work mode. - Hibrído</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="work_mode_vs_AI_replace_dev_QWbZj"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 66% |
# | maybe_in_10+_years | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by work mode. - none</em></p>
#     <br/>
# </center>

# %% [markdown]
# ## AI replacement vs. employment_mode

# %%
# Mostrar valores unicos en columna 'employment mode'.
get_column_uniques(df, "employment_mode")
# Out:
# ['Empleador local (Paraguay)',
#  'foreign_employer',
#  'freelance',
#  'local_with_foreign_clients']

# %%
grouped_grid_barh_chart(
    df.groupby("employment_mode"),
    "AI_replace_dev",
    "AI replacement by 'employment mode'.",
    4,
    1,
    "gray",
    8.5,
)

# %% [markdown]
# ## AI replacement vs. prog_skills_in_role

# %%
grouped_grid_barh_chart(
    df.groupby("prog_skills_in_role"),
    "AI_replace_dev",
    "AI replacement by 'prog_skills_in_role'.",
    24,
    1,
    "gray",
    8.5,
)

# %% [markdown]
# ## AI replacement vs. code_for_job

# %% [markdown]
# ## AI replacement vs. IT_exp

# %%
md_group_table(
    "IT_exp_vs_AI_replace_dev",
    df,
    "IT_exp",
    "AI_replace_dev",
    "Will AI replace devs? \n by IT experiece in years.",
)
# Out:
# <center>
#     <a id="IT_exp_vs_AI_replace_dev_ZrSrW"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 55% |
# | maybe_in_10+_years | 32% |
# | Sí | 11% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by IT experiece in years. - 18_25 years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_AI_replace_dev_iqAtH"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 61% |
# | maybe_in_10+_years | 36% |
# | Sí | 2% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by IT experiece in years. - 3_5 years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_AI_replace_dev_8vMKJ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 62% |
# | maybe_in_10+_years | 33% |
# | Sí | 3% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by IT experiece in years. - 10_12 years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_AI_replace_dev_zgh1y"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 73% |
# | maybe_in_10+_years | 21% |
# | Sí | 5% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by IT experiece in years. - 26+ years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_AI_replace_dev_BtDTJ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 75% |
# | maybe_in_10+_years | 22% |
# | Sí | 2% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by IT experiece in years. - 13_17 years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_AI_replace_dev_6S3FY"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 68% |
# | maybe_in_10+_years | 29% |
# | Sí | 2% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by IT experiece in years. - 6_9 years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_AI_replace_dev_aUPnq"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 62% |
# | maybe_in_10+_years | 34% |
# | Sí | 3% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by IT experiece in years. - 1_2 years</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="IT_exp_vs_AI_replace_dev_bRbPU"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | maybe_in_10+_years | 57% |
# | No | 42% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by IT experiece in years. - <1 year</em></p>
#     <br/>
# </center>

# %% [markdown]
# ## AI replacement vs. prof_prog_exp

# %%
grouped_grid_barh_chart(
    df.groupby("prof_prog_exp"),
    "AI_replace_dev",
    "AI replace devs by 'prof_prog_exp'.",
    14,
    1,
    "gray",
    8.5,
)

# %% [markdown]
# ## AI replacement vs. majors

# %%
md_group_table(
    "majors_vs_AI_replace_dev",
    df,
    "majors",
    "AI_replace_dev",
    "Will AI replace devs? \n by majors.",
)
# Out:
# <center>
#     <a id="majors_vs_AI_replace_dev_KDCSY"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 60% |
# | maybe_in_10+_years | 39% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - systems_analysis</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_hD8lR"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis, computer_engineering, electronic_engineering, graphic_design</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_69SMN"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 63% |
# | maybe_in_10+_years | 36% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_V2lU0"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 85% |
# | maybe_in_10+_years | 14% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, computer_engineering</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_kbcfP"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Sí | 50% |
# | No | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis, computer_engineering, mathematics</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_CT86h"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 60% |
# | maybe_in_10+_years | 40% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - systems_analysis, computer_engineering</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_quqwd"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 74% |
# | maybe_in_10+_years | 23% |
# | Sí | 2% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_N0weC"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 71% |
# | maybe_in_10+_years | 28% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - electronic_engineering</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_jOJgc"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 64% |
# | maybe_in_10+_years | 29% |
# | Sí | 5% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - computer_engineering</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_kDBPq"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 55% |
# | maybe_in_10+_years | 37% |
# | Sí | 7% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis, computer_engineering</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_Q5OtI"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 50% |
# | maybe_in_10+_years | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - none</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_gnMDx"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 50% |
# | maybe_in_10+_years | 25% |
# | Sí | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - computer_engineering, other</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_MUEJ6"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | maybe_in_10+_years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - systems_analysis, computer_engineering, other ingenerías</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_toiwN"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - other ingenerías</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_IWj0M"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis, computer_engineering, other ingenerías</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_PPZac"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 75% |
# | maybe_in_10+_years | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, other</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_AGkLo"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 85% |
# | maybe_in_10+_years | 14% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - other</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_mXXT5"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - systems_analysis, computer_engineering, other</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_aguAU"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 50% |
# | maybe_in_10+_years | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis, computer_engineering, mathematics, other</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_Dk5NQ"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, graphic_design, other</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_aiOFg"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 50% |
# | maybe_in_10+_years | 33% |
# | Sí | 16% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis, other</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_wVmCl"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, other ingenerías</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_q7VfY"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - systems_analysis, civil_engineering</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_ApHva"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | maybe_in_10+_years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - mathematics, none</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_GcWEo"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - computer_engineering, mathematics</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_KmNx2"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - graphic_design</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_UO4Hq"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | maybe_in_10+_years | 50% |
# | No | 50% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, computer_engineering, other</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_we5VV"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | maybe_in_10+_years | 75% |
# | No | 25% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis, graphic_design</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_OLXvw"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | maybe_in_10+_years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis, electronic_engineering, other ingenerías, other</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_wFGpp"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | maybe_in_10+_years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - other ingenerías, other</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_dA48I"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | maybe_in_10+_years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis, computer_engineering, other</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_LdCZt"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 66% |
# | maybe_in_10+_years | 33% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis, mathematics</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_bGpq5"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | maybe_in_10+_years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, electronic_engineering, other</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_jHW54"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | Sí | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis, computer_engineering, electrical_engineering</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_f0HiK"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - electrical_engineering</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_6OPRK"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | maybe_in_10+_years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, electronic_engineering, mathematics</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_o72WT"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis, civil_engineering</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_6gzp9"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | maybe_in_10+_years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis, computer_engineering, graphic_design</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_In1Zz"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | maybe_in_10+_years | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis, mathematics, other</em></p>
#     <br/>
# </center>
#
#
#
#
#
#
# <center>
#     <a id="majors_vs_AI_replace_dev_HQfLW"></a>
#     <br/>
#     <br/>
#     <div style="text-align: center;">
#     | Category | Percentage |
# |-------|-------------|
#     | No | 100% |
#     </div>
#     <br/>
#     <p style="text-align: center;"><em>Will AI replace devs?
#  by majors. - programming, systems_analysis, electronic_engineering</em></p>
#     <br/>
# </center>

# %% [markdown]
# ## AI replacement vs. gender

# %%
grouped_grid_barh_chart(
    df.groupby("gender"),
    "AI_replace_dev",
    "AI replacement by 'gender'.",
    5,
    1,
    "gray",
    8.5,
)

# %% [markdown]
# ## AI replacement vs. age

# %%
plt.rcParams["figure.figsize"] = [22, 7]

grouped_grid_barh_chart(
    df.groupby("AI_replace_dev"),
    "age",
    "AI replacement by 'age'.",
    15,
    1,
    "gray",
    8.5,
)
